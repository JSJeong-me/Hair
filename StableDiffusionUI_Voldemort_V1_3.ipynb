# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/Hair/blob/main/StableDiffusionUI_Voldemort_V1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Adapted from: https://colab.research.google.com/drive/1AfAmwLMd_Vx33O9IwY2TmO9wKZ8ABRRa

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd stable-diffusion-webui
#@title SD1.5
# get a token from https://huggingface.co/settings/tokens
user_token = "A guy has hair style that is long layer cut and natural flow perm." #@param {type:"string"}
user_header = f"\"Authorization: Bearer {user_token}\""
# !wget --header={user_header} https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned.ckpt -O /content/stable-diffusion-webui/model.ckpt
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 23951, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 23951 (delta 69), reused 81 (delta 50), pack-reused 23836
# Receiving objects: 100% (23951/23951), 31.04 MiB | 18.48 MiB/s, done.
# Resolving deltas: 100% (16769/16769), done.
# /content/stable-diffusion-webui
# --2023-07-23 23:25:28--  https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned.ckpt
# Resolving huggingface.co (huggingface.co)... 65.9.86.57, 65.9.86.62, 65.9.86.79, ...
# Connecting to huggingface.co (huggingface.co)|65.9.86.57|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/6b/20/6b201da5f0f5c60524535ebb7deac2eef68605655d3bbacfee9cce0087f3b3f5/e1441589a6f3c5a53f5f54d0975a18a7feb7cdf0b0dee276dfc3331ae376a053?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27v1-5-pruned.ckpt%3B+filename%3D%22v1-5-pruned.ckpt%22%3B&Expires=1690403422&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=B0IU0YWXVqV3pcqrwNxeONCW9VZrU0DmcJt8JT66UBwLMVfM0CBXQVgN2f%7EEI7-aolDbHoEG%7EpsKgYlrr4tog1simXS0KR4C7p6DOPK73rWKwru7B2GeZOmlUWXnDpMbFoRUqtChO3r98LLKZcOmh%7E%7EPV%7EMmf8KyuXKDB2a6bCUdi4IYGZzLJWLSRIFJpBRemUZXqdDE8yANQiRZE1xKhhLNi6e8PGvDRSUeYaIC%7ExhiLuhDNO-t7R%7Egcyz6RT9AopsO7zpH-fpILlka799DyCM02WtwIzE6wwzooacQGRua-U-LJ%7EV3pdw-7ww3%7EkxOvdVWBQaOiN0pmT0%7EvIpq4A__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-07-23 23:25:29--  https://cdn-lfs.huggingface.co/repos/6b/20/6b201da5f0f5c60524535ebb7deac2eef68605655d3bbacfee9cce0087f3b3f5/e1441589a6f3c5a53f5f54d0975a18a7feb7cdf0b0dee276dfc3331ae376a053?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27v1-5-pruned.ckpt%3B+filename%3D%22v1-5-pruned.ckpt%22%3B&Expires=1690403422&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=B0IU0YWXVqV3pcqrwNxeONCW9VZrU0DmcJt8JT66UBwLMVfM0CBXQVgN2f%7EEI7-aolDbHoEG%7EpsKgYlrr4tog1simXS0KR4C7p6DOPK73rWKwru7B2GeZOmlUWXnDpMbFoRUqtChO3r98LLKZcOmh%7E%7EPV%7EMmf8KyuXKDB2a6bCUdi4IYGZzLJWLSRIFJpBRemUZXqdDE8yANQiRZE1xKhhLNi6e8PGvDRSUeYaIC%7ExhiLuhDNO-t7R%7Egcyz6RT9AopsO7zpH-fpILlka799DyCM02WtwIzE6wwzooacQGRua-U-LJ%7EV3pdw-7ww3%7EkxOvdVWBQaOiN0pmT0%7EvIpq4A__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.65.39.13, 18.65.39.78, 18.65.39.62, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.65.39.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7703807346 (7.2G) [binary/octet-stream]
# Saving to: ‘/content/stable-diffusion-webui/model.ckpt’
#
# /content/stable-dif 100%[===================>]   7.17G   239MB/s    in 37s
#
# 2023-07-23 23:26:06 (197 MB/s) - ‘/content/stable-diffusion-webui/model.ckpt’ saved [7703807346/7703807346]

# %% [markdown]
# Launch web ui. You will get a link to nnn.gradio.app, follow it.
#
# Commandline arguments are:
#   - `--share` - create online gradio.app link
#   - `--gradio-debug` - print outputs to console
#   - optional: `--gradio-auth me:qwerty` - add authentication to gradio: username me, password qwerty
#   - see [wiki](https://github.com/AUTOMATIC1111/stable-diffusion-webui/wiki/Command-Line-Arguments-and-Settings) for more options

# %%
# !COMMANDLINE_ARGS="--share --gradio-debug --gradio-auth me:qwerty" REQS_FILE="requirements.txt" python launch.py
# Out:
# Python 3.10.6 (main, May 29 2023, 11:10:38) [GCC 11.3.0]
# Version: v1.4.1
# Commit hash: f865d3e11647dfd6c7b2cdf90dde24680e58acd8
# Installing gfpgan
# Installing clip
# Installing open_clip
# Cloning Stable Diffusion into /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai...
# Cloning K-diffusion into /content/stable-diffusion-webui/repositories/k-diffusion...
# Cloning CodeFormer into /content/stable-diffusion-webui/repositories/CodeFormer...
# Cloning BLIP into /content/stable-diffusion-webui/repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements
# Launching Web UI with arguments: --share --gradio-debug --gradio-auth me:qwerty
# 2023-07-23 23:27:47.066594: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-23 23:27:48.265290: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Traceback (most recent call last):
#   File "/content/stable-diffusion-webui/launch.py", line 38, in <module>
#     main()
#   File "/content/stable-diffusion-webui/launch.py", line 34, in main
#     start()
#   File "/content/stable-diffusion-webui/modules/launch_utils.py", line 340, in start
#     import webui
#   File "/content/stable-diffusion-webui/webui.py", line 42, in <module>
#     from modules.call_queue import wrap_gradio_gpu_call, wrap_queued_call, queue_lock  # noqa: F401
#   File "/content/stable-diffusion-webui/modules/call_queue.py", line 5, in <module>
#     from modules import shared, progress, errors
#   File "/content/stable-diffusion-webui/modules/shared.py", line 18, in <module>
#     from ldm.models.diffusion.ddpm import LatentDiffusion
#   File "/content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/models/diffusion/ddpm.py", line 20, in <module>
#     from pytorch_lightning.utilities.distributed import rank_zero_only
# ModuleNotFoundError: No module named 'pytorch_lightning.utilities.distributed'

# %% [markdown]
# commands for ***after*** you have gotten done with a session
# ============================================================================

# %% [markdown]
# Zip images for downloading on local drive (click the folder icon on the left, the one below {x})

# %%
# !zip -r /content/stable-diffusion-webui /content/stable-diffusion-webui/outputs

# %% [markdown]
# Save images to Google Drive **Warning: this will cause google to scan your drive, so if you intend to use this and worry about that kind of stuff, probablly just set this up on a clean account that's just for this colab**

# %%
from google.colab import drive # type: ignore

try:
   drive_path = "/content/drive"
   drive.mount(drive_path,force_remount=False)
except:
   print("...error mounting drive or with drive path variables")

# !cp -r "/content/stable-diffusion-webui/outputs" "/content/drive/MyDrive"
