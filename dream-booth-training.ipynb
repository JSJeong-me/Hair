# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/Hair/blob/main/dream-booth-training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### https://www.youtube.com/watch?v=gF078Lhnr94

# %%
# !pip install -U autotrain-advanced
