# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/Hair/blob/main/LoRA_Model_Copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cp /content/drive/MyDrive/Loras/TEXTURE_LoRA/output/TEXTURE_LoRA-12.safetensors /content/drive/MyDrive/digiclau_lab/Lora

# %%
# !cp /content/drive/MyDrive/Loras/TEXTURE_LoRA/output/TEXTURE_LoRA-12.safetensors /content/drive/MyDrive/digiclau_lab/Lora

# %%
# !cp /content/drive/MyDrive/Loras/AIL_LoRA/output/AIL_LoRA-12.safetensors /content/drive/MyDrive/digiclau_lab/Lora

# %%
# !cp /content/drive/MyDrive/Loras/GAIL_LoRA/output/GAIL_LoRA-12.safetensors /content/drive/MyDrive/digiclau_lab/Lora

# %%
# !cp /content/drive/MyDrive/Loras/CROP_LoRA/output/CROP_LoRA-12.safetensors /content/drive/MyDrive/digiclau_lab/Lora
